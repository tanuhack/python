# %%
import numpy as np
from scipy.stats import norm
import matplotlib as mpl
import matplotlib.pyplot as plt

# # fivethirtyeightスタイルを使う
# mpl.style.use(style='fivethirtyeight')

# Jupyter Notebookに描画する
# %matplotlib inline

# %%
n = np.linspace(-4.0, 4.0, 1000)
norm.pdf(n, loc=0, scale=1)
# Out:
# array([1.33830226e-04, 1.38182046e-04, 1.42666228e-04, 1.47286482e-04,
#        1.52046611e-04, 1.56950518e-04, 1.62002199e-04, 1.67205753e-04,
#        1.72565380e-04, 1.78085384e-04, 1.83770176e-04, 1.89624276e-04,
#        1.95652315e-04, 2.01859035e-04, 2.08249298e-04, 2.14828081e-04,
#        2.21600482e-04, 2.28571723e-04, 2.35747150e-04, 2.43132240e-04,
#        2.50732599e-04, 2.58553964e-04, 2.66602213e-04, 2.74883358e-04,
#        2.83403556e-04, 2.92169106e-04, 3.01186456e-04, 3.10462203e-04,
#        3.20003096e-04, 3.29816041e-04, 3.39908104e-04, 3.50286511e-04,
#        3.60958652e-04, 3.71932089e-04, 3.83214551e-04, 3.94813945e-04,
#        4.06738352e-04, 4.18996037e-04, 4.31595448e-04, 4.44545221e-04,
#        4.57854181e-04, 4.71531351e-04, 4.85585949e-04, 5.00027396e-04,
#        5.14865316e-04, 5.30109544e-04, 5.45770125e-04, 5.61857322e-04,
#        5.78381615e-04, 5.95353710e-04, 6.12784538e-04, 6.30685261e-04,
# ...

# %%
n = np.linspace(-4.0, 4.0, 10000)

# # 平均0, 標準偏差1の正規分布における、xの確率を求める
# p = []
# for i in range(len(n)):
#     p.append(norm.pdf(x=n[i], loc=0, scale=1))
    
    
fig, ax = plt.subplots(figsize=(6, 6), dpi=144)
ax.axis('off')
ax.plot(n, norm.pdf(n, loc=0, scale=1), color='#F4CC04', lw=3)

ax.vlines(x=range(-3, 4, 1), ymin=0, ymax=norm.pdf(range(-3, 4, 1), loc=0, scale=1), colors='#EDEDED')

plt.savefig(fname='/Users/tanu/Desktop/norm.png', transparent=True, dpi=fig.get_dpi(), bbox_inches='tight')

# %%
norm.pdf(0, loc=0, scale=1)
# Out:
# 0.3989422804014327

# %%
list(range(-3, 4, 1))
# Out:
# [-3, -2, -1, 0, 1, 2, 3]
